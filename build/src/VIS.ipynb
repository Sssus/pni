# %%
import img_util, glob
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img_patch_list = glob.glob('../patches/Col/0025/image/*.png')
target_patch_list = glob.glob('../patches/Col/0025/mask/*.png')
img_patch_list = glob.glob('./sam/col/0002/image/*.png')[:2]
target_patch_list = glob.glob('./sam/col/0002/mask/*.png')[:2]
img_target_pairs = list(zip(img_patch_list,target_patch_list))

# %%
for pair in img_target_pairs:
    x,y = pair
    img_util.visualize_patch(x,y)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FB829888630>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FB829888630>

# %%
img = cv.imread(y,0)
d = np.unique(img,return_counts=True)

plt.bar(x = d[0],height=d[1])
# Out:
# <BarContainer object of 2 artists>
